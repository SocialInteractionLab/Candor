# %% [markdown]
# ## Setup

# %%
# install packages as needed
#! pip install sentence-transformers
#! pip install numpy
#! pip install pandas
#! pip install scikit-learn
#! pip install matplotlib
#! pip install numpy==1.24.1

# %%
# libraries
from sentence_transformers import SentenceTransformer
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import sklearn
from sklearn import cluster
from sklearn.cluster import KMeans
# Out:
# /opt/anaconda3/envs/myenv-python3-9/lib/python3.9/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
# load pre-trained sentence transformer model (aka SBERT)
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# /opt/anaconda3/envs/myenv-python3-9/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# ## TILE
# ### 3-utterance tiling for all annotated conversations

# %%
# create a function to get tiled cosine similarities between aggregated utterances
def tiled_cosine_similarity(df, window_size):
    # create empty list to store output
    results = []
    # iterate over each group of transcript_id
    for transcript_id, group in df.groupby('transcript_id'):
        # sort by turn_id to maintain conversation order
        group = group.sort_values(by = "turn_id")
        # extract all utterances for this transcript
        utterances = group['utterance'].tolist()
        print(f"Length utterances = {len(utterances)} for transcript {transcript_id}")
        # now move to sliding window approach to get similarity between consecutive windows
        for i in range(len(utterances) - window_size):
            #i = i + 2
            # get start row and end row of window A
            A_start = i # inclusive
            A_end = A_start + window_size # exclusive
            window_A = df['utterance'].iloc[A_start:A_end].str.cat(sep = " ")
            # get start row and end row of window B
            B_start = i + window_size
            B_end = B_start + window_size
            window_B = df['utterance'].iloc[B_start:B_end].str.cat(sep = " ")
            # ensure that both windows are not empty
            if len(window_A) > 0 and len(window_B) > 0:
                # get embeddings for both windows
                embeddings_A = model.encode(window_A)
                embeddings_B = model.encode(window_B)
                # ensure embeddings are 2D arrays
                embeddings_A = embeddings_A.reshape(1, -1)
                embeddings_B = embeddings_B.reshape(1, -1)
                # alert me if embeddings have different shapes
                assert embeddings_A.shape[1] == embeddings_B.shape[1], \
                    f"Dimensionality mismatch: A={embeddings_A.shape[1]}, B={embeddings_B.shape[1]}"
                # get cosine similarity between utterances in windows A and B
                similarity = cosine_similarity(embeddings_A, embeddings_B)
                # save output
                output = {
                    'transcript_id': transcript_id,
                    'window_size': window_size,
                    'A_start_turn': A_start + 1, # account for 0-bounding python
                    'A_end_turn': A_end,
                    'A_utterances': window_A,
                    'B_start_turn': B_start + 1, # account for 0-bounding python
                    'B_end_turn': B_end,
                    'B_utterances': window_B,
                    'cosine_similarity': similarity[0][0]
                }
                results.append(output)
    # convert results list to data frame and return
    results_df = pd.DataFrame(results)
    print(results_df.head())
    return results_df

# %%
# load annotated conversations
# hs home
df = pd.read_csv("/Users/helenschmidt/Library/CloudStorage/GoogleDrive-helenschmidt129@gmail.com/My Drive/SANLab/Experiments/Conversation-Structure/data/processed/backbiter_subset_for_tiling.csv")
# lab
# df = pd.read_csv()

# make sure data is pandas dataframe
df = pd.DataFrame(df)
# preview
df.head()
# Out:
#    turn_id                   speaker                         transcript_id  \
# 0        0  5ad7c075c25ea0000188486b  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 1        1  5de5538f8fde1c4dbc951498  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 2        2  5ad7c075c25ea0000188486b  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 3        3  5de5538f8fde1c4dbc951498  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 4        4  5ad7c075c25ea0000188486b  01849238-f5f0-487e-bca4-7b4fe0c9625c
#
#                                            utterance
# 0  mm. Mhm. Okay. Okay. Mm hmm. Mhm. Oh. Mhm. Oka...
# 1  Hello, Can you hear me? I can, how are you doing?
# 2                               Good. How about you?
# 3                             I am doing well, yeah,
# 4  Sweet. So um I guess we could start off by tal...

# %%
# apply tiling function to annotated conversations with window size of 3
full_tile_3 = tiled_cosine_similarity(df, 3)
# Out:
# Length utterances = 348 for transcript 01849238-f5f0-487e-bca4-7b4fe0c9625c
# Length utterances = 596 for transcript 01a4c01c-cf0e-4f37-ab2b-641bb604af30
# Length utterances = 232 for transcript 04542d1a-168a-4f90-b7e3-33adb675525f
# Length utterances = 589 for transcript 0542c0f0-6c1e-4e54-b3df-afa48b19f9b5
# Length utterances = 301 for transcript 06afb9c1-b367-45c7-a9ff-74c47a2cb61c
# Length utterances = 683 for transcript 06b83c0a-7bf1-4cf9-9e72-034615d97050
# Length utterances = 317 for transcript 07094abd-8b2a-426a-8dca-edead45c2143
# Length utterances = 176 for transcript 0736fa95-99e8-4707-bd64-4552eb79d05a
# Length utterances = 191 for transcript 0a294776-ca94-4114-bc24-2bf3b0a0a813
# Length utterances = 260 for transcript 0b019c01-a6b7-4753-afa3-f7bf964932c9
# Length utterances = 140 for transcript 0bd4dd2c-1cf0-46fb-87d3-a88b1de310a6
# Length utterances = 413 for transcript 0bfe2cba-bf84-4a8b-887d-f19378aa07d8
# Length utterances = 271 for transcript 0e772ef8-9014-48a8-8eb9-762ef55b4fe9
# Length utterances = 260 for transcript 0e8d198c-fe6c-400c-a88b-5a3ead8567bc
# Length utterances = 546 for transcript 128f15b9-a6e4-4575-8b96-163ff189ee8e
# Length utterances = 307 for transcript 12a3510d-960d-4ce2-9933-f473f4ee6800
# Length utterances = 331 for transcript 12b1692d-699f-430c-81bf-8f2add0796f5
# Length utterances = 330 for transcript 15fe8c92-30ba-47f5-a0ea-44a1cd47dba7
# Length utterances = 319 for transcript 19c78684-fc44-482c-a0d3-d19223b4ba65
# Length utterances = 354 for transcript 1f7e582c-c6bc-46b6-b5a4-e5d78e8a46ac
# Length utterances = 360 for transcript 208392ba-e44a-4d2b-be77-1927ad69bc5e
# Length utterances = 179 for transcript 20c21d82-037a-4faf-a439-e8be15daf201
# Length utterances = 426 for transcript 22083989-6244-440b-af5b-93a3a10f6e04
# Length utterances = 499 for transcript 22938143-89e2-445c-b3cc-d3503abeda83
# Length utterances = 196 for transcript 23a1437e-4761-42c9-8bbd-48cdf86c09ff
# Length utterances = 286 for transcript 243349a8-ddca-43f5-bfa7-3ece849fc8e5
# Length utterances = 319 for transcript 25262e9d-0157-4bc2-a7aa-ce0f1509e075
# Length utterances = 467 for transcript 263fc615-bee8-48a5-8a1f-28bff46ec228
# Length utterances = 321 for transcript 2c92dd3e-6e7a-4968-871d-5674790e7a74
# Length utterances = 282 for transcript 2d271d93-fc72-43ed-9e2f-18ff188d5875
# Length utterances = 264 for transcript 2ec76af8-c231-488a-95bf-4269bef6996b
# Length utterances = 304 for transcript 2ef0bddb-04a7-4d0e-8aba-fa7c313e5295
# Length utterances = 318 for transcript 2fae6aa6-182c-4caf-84d3-09bd505cb5e1
# Length utterances = 108 for transcript 30a5a4ba-5ca5-465f-8a8f-cda3d7737662
# Length utterances = 189 for transcript 310ce55b-8db0-4407-a25c-c2460b37cce5
# Length utterances = 377 for transcript 31a7caa4-f825-4995-8d4d-2126124ff47c
# Length utterances = 253 for transcript 330137c3-3b27-4eab-95b6-ff26b2aa2c0f
# Length utterances = 323 for transcript 33528414-6a77-4fde-a01a-aebbad5fc3d8
# Length utterances = 511 for transcript 358be89b-e916-4553-8f40-f9dcd1da006e
# Length utterances = 476 for transcript 36fc65e0-03f6-4a9e-8f6d-b9072197ffba
# Length utterances = 1264 for transcript 373764f7-6987-485a-8739-51f37cb46e3d
# Length utterances = 234 for transcript 3a47cc58-f351-4050-b06f-a0b505f2e7da
# Length utterances = 276 for transcript 3b130d42-5bfd-41c0-a5a0-30779f70b65a
# Length utterances = 277 for transcript 3d05e6d6-51f2-4365-b6eb-c6a8621c3a27
# Length utterances = 243 for transcript 3de1bfb4-526d-4d0b-93d0-7f763b9a6de7
# Length utterances = 351 for transcript 3e3beb5d-0b8c-4be1-99f5-c6175a3a57c3
# Length utterances = 194 for transcript 419c2d57-3d26-4c4e-a5a5-de392846532f
# Length utterances = 338 for transcript 42d99fff-daee-41bc-ba4a-55b6a787e51d
# Length utterances = 283 for transcript 432efb26-fdcd-4a4c-8fa1-11310c0b96e3
# Length utterances = 455 for transcript 437d7142-ef5c-4c73-a958-21e32cd3a75a
# Length utterances = 442 for transcript 46e04d30-d787-40ea-a84e-95222ee4a17b
# Length utterances = 250 for transcript 474ab563-0623-448f-b2f6-13505ae80fa4
# Length utterances = 756 for transcript 4b3fc3a3-8714-407c-b142-bf2e242e0ae9
# Length utterances = 295 for transcript 4d094d13-35ca-4a09-b918-b23f185e6340
# Length utterances = 185 for transcript 4e02e612-69a5-4323-8610-e89822241fc2
# Length utterances = 235 for transcript 4e116092-0c94-4f33-b6c5-7a7c7a54b60d
# Length utterances = 210 for transcript 4ec6a831-5dda-4109-84cd-5e376c29e920
# Length utterances = 291 for transcript 4f4d07f8-cd05-4330-b446-6b314915be49
# Length utterances = 292 for transcript 5057bc37-07d8-4149-a206-ab98231e2980
# Length utterances = 316 for transcript 52e38736-df36-4dfc-97c3-7f7a2ca790ad
# Length utterances = 249 for transcript 53074503-e206-4f9f-8e46-0c767ff6813f
# Length utterances = 113 for transcript 541ddc3c-ae0c-435d-a503-84abd0558534
# Length utterances = 196 for transcript 5608d91f-46c6-441e-94b3-8ca42d28b915
# Length utterances = 417 for transcript 56529e73-480c-43fa-b313-a0bd3d8f033e
# Length utterances = 269 for transcript 582ea058-c65e-4739-aaac-46d498956317
# Length utterances = 289 for transcript 588c5b4b-5e92-426c-8acc-686628a7342f
# Length utterances = 350 for transcript 59bb81e4-9c3c-4b4d-8343-5f7c5f3ab9d5
# Length utterances = 286 for transcript 5a6f9b34-17b2-4a65-95e1-7af5b451b395
# Length utterances = 372 for transcript 5c6f6632-c722-4041-9d36-5ada31c42471
# Length utterances = 528 for transcript 5c91528b-686c-4446-82dc-5dd830d4d7b1
# Length utterances = 335 for transcript 5ca462a1-d50f-4219-be29-16b4151a3639
# Length utterances = 213 for transcript 5ca82a7c-ef99-444e-9147-c957ad9632ba
# Length utterances = 331 for transcript 5d106c0f-e40f-453c-b1a4-3b90e3cb8b4c
# Length utterances = 266 for transcript 5d802b9e-b047-450a-9695-69c10a96699f
# Length utterances = 557 for transcript 607a1155-0781-43a4-88ea-66a4cdb75585
# Length utterances = 552 for transcript 6365a56e-c7bc-4f08-9828-08537508f71d
# Length utterances = 225 for transcript 6aa2e640-173d-4b2c-a59e-845d46b6c139
# Length utterances = 534 for transcript 6ce9f678-15c4-424c-bf3f-b4e2f47a8818
# Length utterances = 649 for transcript 6ec9ed5c-3b53-4661-bb3c-e83308de804f
# Length utterances = 240 for transcript 6f6900a6-098d-4034-aa06-43339769adbe
# Length utterances = 360 for transcript 7193181e-85e5-4c31-96f7-d4f38c312f71
# Length utterances = 189 for transcript 725b5586-09b0-4701-a975-03bbd6b88edf
# Length utterances = 540 for transcript 72a00e54-457f-423a-92a7-0df30ec6a811
# Length utterances = 268 for transcript 748a93e0-323c-444d-985c-6540295e26de
# Length utterances = 7 for transcript 765f6cde-5291-4047-89c1-d71b1e3a413d
# Length utterances = 469 for transcript 76abad1d-daf9-4cc6-bf7b-9520438a66f9
# Length utterances = 139 for transcript 776df112-4de3-40af-8db6-74adffe95ace
# Length utterances = 311 for transcript 782a11f3-337b-4794-8888-82aca3675442
# Length utterances = 197 for transcript 78d88191-8981-4da8-b232-3e2153d9b599
# Length utterances = 545 for transcript 7944f706-b354-4953-9a17-9ca60a5d6d16
# Length utterances = 445 for transcript 7c80ae4c-14c0-469b-b254-6ea3dc876e24
# Length utterances = 1352 for transcript 7cfa2470-f77f-42a6-98b1-9e2e4ef61cdb
# Length utterances = 147 for transcript 7fc59ebb-a980-4df1-9d39-f15ae25f3f27
# Length utterances = 154 for transcript 81d35bc9-a18c-4501-956b-02c8a5e1b292
# Length utterances = 367 for transcript 830bf9eb-68ff-470d-bc84-a87454d31f9f
# Length utterances = 545 for transcript 832b10fd-545f-4001-9eb3-3804c774272e
# Length utterances = 418 for transcript 844752ba-d440-4c9c-8a90-f8e641c4b305
# Length utterances = 196 for transcript 85bb0a1d-9632-4786-9e7e-cc97bbe5b632
# Length utterances = 343 for transcript 885fbe61-96bb-4644-8629-9af34557eacf
# Length utterances = 212 for transcript 89030a65-7fbf-4b75-a85b-e0b48c9cb21d
# Length utterances = 460 for transcript 8942bbbe-ac20-48ab-9c7c-c69098c99a42
# Length utterances = 340 for transcript 8a9561f0-0eb6-4650-be92-4bb03821fb7b
# Length utterances = 688 for transcript 916d8851-e042-42e8-9dd5-9aa61c3e8df0
# Length utterances = 174 for transcript 91fd5018-5302-4a6b-8699-eb56c370e5e4
# Length utterances = 146 for transcript 939a1017-c474-4059-9dac-1ae65a2e4bcf
# Length utterances = 252 for transcript 956c58d0-48d4-4f4a-8cee-95c4b2df5e58
# Length utterances = 317 for transcript 9621ea79-3d5b-4b49-aa09-d792aa9a23e1
# Length utterances = 516 for transcript 97237153-37f6-48f0-a8ea-45ab74ccb18a
# Length utterances = 254 for transcript 97b17342-a9c0-43ed-ad4f-02dfebfb7ce7
# Length utterances = 339 for transcript 98666aa9-2a23-4a64-9379-48541d73d901
# Length utterances = 185 for transcript 9888a348-46ae-4941-a37b-b1955439f958
# Length utterances = 516 for transcript 990143a6-5b72-4ab3-b87b-b3b558bc0d11
# Length utterances = 458 for transcript 9e11ca71-f442-49d4-a9c0-3c7ba4afa275
# Length utterances = 212 for transcript 9f3ab90a-2c3c-4774-a703-f6188d446397
# Length utterances = 373 for transcript 9f3d1985-bfa4-48c5-95c1-a38d4a0dd4a1
# Length utterances = 217 for transcript a003874c-1d39-4924-857f-94a865951ae9
# Length utterances = 439 for transcript a16e426d-757b-44ea-bd45-1f04912427c5
# Length utterances = 294 for transcript a1a0b592-b2dc-4abe-bb4f-a29ecb6e88fa
# Length utterances = 260 for transcript a2c3d859-d4ec-467e-931c-a8db11edfa65
# Length utterances = 175 for transcript a6f97713-f548-4833-9f9d-62f25dc91a44
# Length utterances = 353 for transcript a7602f19-a879-4ec7-8653-dfb750095c6e
# Length utterances = 611 for transcript a8855c03-359f-42d9-af04-e459f9547107
# Length utterances = 351 for transcript a90526ed-4c07-411f-893d-b4974747080f
# Length utterances = 209 for transcript a90c2314-ab8b-4ce9-8af5-ad40ed4f5613
# Length utterances = 723 for transcript aa0147bf-1fd7-4690-a994-8d5a31592cf5
# Length utterances = 326 for transcript aaa30e9f-886f-403f-a16e-6eff8b86f565
# Length utterances = 1617 for transcript ab642b9e-2060-4c49-86c3-92cfc0c865f0
# Length utterances = 460 for transcript abb4c7de-38ff-4ca0-aff2-7411f055a758
# Length utterances = 398 for transcript acd5c3b5-c080-4ab4-98ca-4099c2711591
# Length utterances = 189 for transcript ad57691a-0b33-4fcd-80cd-f614bd3b6ef4
# Length utterances = 223 for transcript aecdb078-674d-4aaf-82b9-217b2fcf546c
# Length utterances = 269 for transcript af161134-b61c-4625-a31d-f05538d21909
# Length utterances = 382 for transcript af227a69-6613-4e74-bdc4-b2fd2313eccc
# Length utterances = 371 for transcript afa4d802-a9ed-4b0b-a607-b5f16d899275
# Length utterances = 430 for transcript b0378388-96fa-4564-ab36-305485636ecb
# Length utterances = 423 for transcript b2afb6c2-6049-4861-88a5-f0aeba68b5c8
# Length utterances = 305 for transcript b381599d-5420-4148-acb9-403141f5fb87
# Length utterances = 477 for transcript b524d604-a7b4-4b11-80e5-0a0fe43c5c13
# Length utterances = 213 for transcript b6317fee-af93-40da-ab3e-3f6a12554327
# Length utterances = 658 for transcript b6e249a2-9410-4a2a-8977-5ba0a3119b94
# Length utterances = 260 for transcript b7fae6d8-8246-45ef-a497-c6555e8c10bf
# Length utterances = 219 for transcript b877a5bf-3384-4ea0-bf82-cef399a1b00d
# Length utterances = 204 for transcript b8ca03fb-ba34-49dc-b33f-30b6e9189685
# Length utterances = 255 for transcript b8f9aeaf-a914-45bb-9d7c-7ef83b82f8d3
# Length utterances = 260 for transcript b9cb85c5-1a07-4907-b6c7-0147ad88ab13
# Length utterances = 898 for transcript b9e0eaaa-1013-4a5f-97b7-f1aaa7a04442
# Length utterances = 191 for transcript baf65544-754a-4969-8a8d-41fcc64e83c2
# Length utterances = 258 for transcript bb46db0a-ddc3-4507-94ec-486cbdf9dafb
# Length utterances = 232 for transcript bbc4cee1-25fb-4685-ae2a-b1e7e689f5fe
# Length utterances = 232 for transcript bc13c3ce-399c-4db4-bbd8-a6f21da2ad6e
# Length utterances = 344 for transcript bff43e52-219f-43ad-8329-9ba68c30260f
# Length utterances = 318 for transcript c0775391-b8c3-4884-aaec-ff8b1b5d1de4
# Length utterances = 310 for transcript c0baec1b-3132-4177-941b-c18aec0be57e
# Length utterances = 629 for transcript c0c54a77-1d33-41a4-8e13-92a4840e82b8
# Length utterances = 497 for transcript c135c056-e51a-40f5-ab96-cc9f217f6389
# Length utterances = 261 for transcript c2dccef4-139c-4bc8-98fb-24a521da2923
# Length utterances = 796 for transcript c4149c78-b635-4d4f-9183-53b7e702c95f
# Length utterances = 371 for transcript c500c9ad-c23b-42b5-b17e-8796eedc4e34
# Length utterances = 375 for transcript c7ff1e39-a9c8-47b8-b0fd-f3d176a439c4
# Length utterances = 200 for transcript c82d9523-5682-4b2a-bae0-0a53addeba20
# Length utterances = 348 for transcript c882539b-6f2b-4597-b796-7f1ddb34b595
# Length utterances = 327 for transcript c915492a-293e-4f30-bf49-49bb5faa1bb9
# Length utterances = 312 for transcript ca0e9f0d-3631-407d-96d1-7324ebeb6716
# Length utterances = 179 for transcript ca2928f3-9605-4a2c-93ad-b269bce86c58
# Length utterances = 421 for transcript cb056010-c50e-4e80-b639-bb178a2b9330
# Length utterances = 433 for transcript cb9ee0da-abb1-4985-9d85-6d19cf7cd287
# Length utterances = 301 for transcript cc395184-f776-4bff-9299-e289bfc513f5
# Length utterances = 479 for transcript cc7a5173-9c79-4773-83dc-0d9177bcc524
# Length utterances = 431 for transcript cf9e134e-5240-4c95-b7da-7f9e0ad94a82
# Length utterances = 313 for transcript d00fdeac-2b1d-4c56-9b0b-bf8ef660e5dc
# Length utterances = 405 for transcript d1075180-cd5a-45d0-91cb-cc4a122184dc
# Length utterances = 222 for transcript d37f95f5-973e-4f04-b270-9a5663af6f3b
# Length utterances = 311 for transcript d777011c-80d2-4345-8977-e472d8ef479a
# Length utterances = 665 for transcript d833250c-4b61-40fd-8e8e-039ec127a017
# Length utterances = 190 for transcript d86d16d8-026a-400f-9fc5-b98c56f848a6
# Length utterances = 283 for transcript d95bc9f7-9831-4039-9b7b-59f9d4b4ddcb
# Length utterances = 420 for transcript dc4d280b-baf7-4173-aa45-e80b18fc495c
# Length utterances = 307 for transcript dc614ef9-81f0-44c0-88a4-b40398bd507a
# Length utterances = 283 for transcript de6a2b96-3e92-42b5-b797-508e5e1f59d0
# Length utterances = 234 for transcript dee6cc80-0663-4306-9d62-6d06e4c1ed92
# Length utterances = 264 for transcript e5e34d88-8e4c-49ce-b463-ef1932d89597
# Length utterances = 469 for transcript e696f6a9-e127-4c9b-a47d-541aa078e5e0
# Length utterances = 398 for transcript e82562f4-0dca-4356-83f4-11753a790e79
# Length utterances = 176 for transcript ec397cba-60f5-4bc5-ab02-73a2aaa17029
# Length utterances = 212 for transcript ece26856-e9b0-47d6-a5aa-6090a01adb50
# Length utterances = 387 for transcript ee2f1b3e-81c5-416f-82a2-26d4fcd00198
# Length utterances = 270 for transcript f1f925d9-416a-44d8-9a12-72b975f02459
# Length utterances = 258 for transcript f3eacb84-c7fb-40b8-af8b-4661d9d62a91
# Length utterances = 279 for transcript f458c2ea-1713-41ac-b586-948176c1ab81
# Length utterances = 375 for transcript f7401e31-88f5-42aa-93f5-782981968f72
# Length utterances = 147 for transcript f79d4372-62ac-4e70-a2d9-8b722fd5edc5
# Length utterances = 693 for transcript f7ddd168-2607-4d2b-b01d-905e4e814ba6
# Length utterances = 475 for transcript f81a3aa9-3cb3-4df0-ba18-9b1f6f19e5ba
# Length utterances = 363 for transcript f832c164-64f5-44a3-a0f7-e97c6c8f063d
# Length utterances = 328 for transcript f888a1ee-43b5-49e2-809b-65187ee3e24e
# Length utterances = 315 for transcript f9fd3d3f-3fb9-4036-9976-c7ebcfd1af57
# Length utterances = 384 for transcript fa720f08-9b4a-4fb0-94e9-8cae8d24a5b1
# Length utterances = 420 for transcript fca231e3-c8d1-4e97-b015-94b6c5f505a1
# Length utterances = 381 for transcript fd31814a-0410-4a33-83ff-cb042367e832
# Length utterances = 230 for transcript fe37221d-0db4-43d3-8ceb-41b9c2d917eb
# Length utterances = 437 for transcript ffe29987-3502-4f72-9987-cc5208ae3880
#                           transcript_id  window_size  A_start_turn  \
# 0  01849238-f5f0-487e-bca4-7b4fe0c9625c            3             1
# 1  01849238-f5f0-487e-bca4-7b4fe0c9625c            3             2
# 2  01849238-f5f0-487e-bca4-7b4fe0c9625c            3             3
# 3  01849238-f5f0-487e-bca4-7b4fe0c9625c            3             4
# 4  01849238-f5f0-487e-bca4-7b4fe0c9625c            3             5
#
#    A_end_turn                                       A_utterances  \
# 0           3  mm. Mhm. Okay. Okay. Mm hmm. Mhm. Oh. Mhm. Oka...
# 1           4  Hello, Can you hear me? I can, how are you doi...
# 2           5  Good. How about you? I am doing well, yeah, Sw...
# 3           6  I am doing well, yeah, Sweet. So um I guess we...
# 4           7  Sweet. So um I guess we could start off by tal...
#
#    B_start_turn  B_end_turn  \
# 0             4           6
# 1             5           7
# 2             6           8
# 3             7           9
# 4             8          10
#
#                                         B_utterances  cosine_similarity
# 0  I am doing well, yeah, Sweet. So um I guess we...           0.496188
# 1  Sweet. So um I guess we could start off by tal...           0.413436
# 2  sounds great. I'll let you go first. You look ...           0.379017
# 3                           Well little, just a just           0.204794
# 4                        little, just a just little,           0.171970

# %%
# save tiled data
# hs home
full_tile_3.to_csv("/Users/helenschmidt/Library/CloudStorage/GoogleDrive-helenschmidt129@gmail.com/My Drive/SANLab/Experiments/Conversation-Structure/data/output/annotated_transcripts_tile_3.csv", index = False)
# lab
# full_tile_3.to_csv()

# %% [markdown]
# ## TSNE

# %%
# using same backbiter data (df) from tile section...
# 1: get s-bert word embeddings per utterance 
# 2: reduce embedding dimensionality for each utterance to plot
df.head()
# Out:
#    turn_id                   speaker                         transcript_id  \
# 0        0  5ad7c075c25ea0000188486b  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 1        1  5de5538f8fde1c4dbc951498  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 2        2  5ad7c075c25ea0000188486b  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 3        3  5de5538f8fde1c4dbc951498  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 4        4  5ad7c075c25ea0000188486b  01849238-f5f0-487e-bca4-7b4fe0c9625c
#
#                                            utterance
# 0  mm. Mhm. Okay. Okay. Mm hmm. Mhm. Oh. Mhm. Oka...
# 1  Hello, Can you hear me? I can, how are you doing?
# 2                               Good. How about you?
# 3                             I am doing well, yeah,
# 4  Sweet. So um I guess we could start off by tal...

# %%
# get sbert embeddings for each utterance
def get_embeddings(row):
    # extract current utterance from the row
    current = row['utterance']
    # apply s-bert model to each utterance to get embeddings
    embeddings = model.encode(current)
    return embeddings

# save embeddings 
df['utterance_embedding'] = df.apply(get_embeddings, axis = 1)

# preview 
df.head()
# Out:
#    turn_id                   speaker                         transcript_id  \
# 0        0  5ad7c075c25ea0000188486b  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 1        1  5de5538f8fde1c4dbc951498  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 2        2  5ad7c075c25ea0000188486b  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 3        3  5de5538f8fde1c4dbc951498  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 4        4  5ad7c075c25ea0000188486b  01849238-f5f0-487e-bca4-7b4fe0c9625c
#
#                                            utterance  \
# 0  mm. Mhm. Okay. Okay. Mm hmm. Mhm. Oh. Mhm. Oka...
# 1  Hello, Can you hear me? I can, how are you doing?
# 2                               Good. How about you?
# 3                             I am doing well, yeah,
# 4  Sweet. So um I guess we could start off by tal...
#
#                                  utterance_embedding
# 0  [0.060678475, 0.005255911, -0.0042183995, 0.02...
# 1  [-0.020778073, -0.015140475, 0.013267419, -0.0...
# 2  [0.039609965, -0.01397195, 0.03664549, 0.02249...
# 3  [-0.023786038, -0.08440631, 0.10901276, 0.0035...
# 4  [0.013385294, -0.042186055, 0.023476379, 0.002...

# %%
# make the utterance embeddings into a 2D numpy array (one row per utterance)
tsne_embeddings = np.stack(df['utterance_embedding'].values)
# initialize t-sne
tsne = TSNE(n_components=2, random_state=42)
# apply t-sne
tsne_results = tsne.fit_transform(tsne_embeddings)
# convert results to a data frame
tsne_df = pd.DataFrame(tsne_results, columns=['tsne_1','tsne_2'])

# preview
tsne_df.head()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#       tsne_1     tsne_2
# 0 -33.187672  80.873192
# 1 -30.203676  68.123535
# 2  26.966700  11.603717
# 3  15.368028  11.502008
# 4 -16.766781  20.031582

# %%
# merge tsne results with original data frame
df_tsne = pd.concat([df, tsne_df], axis=1)
# preview
df_tsne.head()
# Out:
#    turn_id                   speaker                         transcript_id  \
# 0        0  5ad7c075c25ea0000188486b  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 1        1  5de5538f8fde1c4dbc951498  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 2        2  5ad7c075c25ea0000188486b  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 3        3  5de5538f8fde1c4dbc951498  01849238-f5f0-487e-bca4-7b4fe0c9625c
# 4        4  5ad7c075c25ea0000188486b  01849238-f5f0-487e-bca4-7b4fe0c9625c
#
#                                            utterance  \
# 0  mm. Mhm. Okay. Okay. Mm hmm. Mhm. Oh. Mhm. Oka...
# 1  Hello, Can you hear me? I can, how are you doing?
# 2                               Good. How about you?
# 3                             I am doing well, yeah,
# 4  Sweet. So um I guess we could start off by tal...
#
#                                  utterance_embedding     tsne_1     tsne_2
# 0  [0.060678475, 0.005255911, -0.0042183995, 0.02... -33.187672  80.873192
# 1  [-0.020778073, -0.015140475, 0.013267419, -0.0... -30.203676  68.123535
# 2  [0.039609965, -0.01397195, 0.03664549, 0.02249...  26.966700  11.603717
# 3  [-0.023786038, -0.08440631, 0.10901276, 0.0035...  15.368028  11.502008
# 4  [0.013385294, -0.042186055, 0.023476379, 0.002... -16.766781  20.031582

# %%
# save tsne data frame
df_tsne.to_csv("/Users/helenschmidt/Library/CloudStorage/GoogleDrive-helenschmidt129@gmail.com/My Drive/SANLab/Experiments/Conversation-Structure/data/output/annotated_transcripts_tsne.csv", index = False)

# %%
# make the embeddings a numpy array
x_test = np.array(df_embeddings)
# set up tsne parameters (pay attention to perplexity)
tsne = TSNE(n_components=2, random_state=10, perplexity=7)
# run tsne on embeddings
x_embedded = tsne.fit_transform(x_test)

# add lines to connect data points
df['TSNE1'] = x_embedded[:, 0]
df['TSNE2'] = x_embedded[:, 1]

# sort by turn order to ensure points plotted in correct order
df = df.sort_values(by='turn_id')

# %% [markdown]
# ## CLUSTER

# %%
# load topic label data to run kmeans clustering and identify clustered labels
cluster = pd.read_csv("/Users/helenschmidt/Library/CloudStorage/GoogleDrive-helenschmidt129@gmail.com/My Drive/SANLab/Experiments/Conversation-Structure/data/processed/all_participant_topic_labels.csv")
# preview
cluster.head()
# Out:
#                                          PID  \
# 0  [False, '66ea5116a642813c3dcf3c6f', None]
# 1  [False, '66ea5116a642813c3dcf3c6f', None]
# 2  [False, '66ea5116a642813c3dcf3c6f', None]
# 3  [False, '66ea5116a642813c3dcf3c6f', None]
# 4  [False, '66ea5116a642813c3dcf3c6f', None]
#
#                           transcript_id          new_topic  topic_order  \
# 0  01849238-f5f0-487e-bca4-7b4fe0c9625c  Starting The Call            1
# 1  01849238-f5f0-487e-bca4-7b4fe0c9625c           Greeting            2
# 2  01849238-f5f0-487e-bca4-7b4fe0c9625c      Introductions            3
# 3  01849238-f5f0-487e-bca4-7b4fe0c9625c             Flying            4
# 4  01849238-f5f0-487e-bca4-7b4fe0c9625c          Schooling            5
#
#    number_of_turns  topic_length
# 0                1         85.01
# 1                2          5.94
# 2                9         23.79
# 3               20         69.43
# 4                1          3.92

# %%
# keep a data frame that has all the labels (PID, turns, topic number in transcript)
# have a second with formatted topic labels (all lowercased, no duplicates) and original topic labels 

# lowercase all topics
cluster['new_topic'] = cluster['new_topic'].str.lower()
cluster.head()
# Out:
#                                          PID  \
# 0  [False, '66ea5116a642813c3dcf3c6f', None]
# 1  [False, '66ea5116a642813c3dcf3c6f', None]
# 2  [False, '66ea5116a642813c3dcf3c6f', None]
# 3  [False, '66ea5116a642813c3dcf3c6f', None]
# 4  [False, '66ea5116a642813c3dcf3c6f', None]
#
#                           transcript_id          new_topic  topic_order  \
# 0  01849238-f5f0-487e-bca4-7b4fe0c9625c  starting the call            1
# 1  01849238-f5f0-487e-bca4-7b4fe0c9625c           greeting            2
# 2  01849238-f5f0-487e-bca4-7b4fe0c9625c      introductions            3
# 3  01849238-f5f0-487e-bca4-7b4fe0c9625c             flying            4
# 4  01849238-f5f0-487e-bca4-7b4fe0c9625c          schooling            5
#
#    number_of_turns  topic_length
# 0                1         85.01
# 1                2          5.94
# 2                9         23.79
# 3               20         69.43
# 4                1          3.92

# %%
def get_embeddings(row):
    # extract current topic from the row
    current = row['new_topic']
    # apply s-bert model to each string to get embeddings
    embeddings = model.encode(current)
    return embeddings

# save embeddings to output
cluster['embeddings'] = cluster.apply(get_embeddings, axis = 1)

cluster.head()
# Out:
#                                          PID  \
# 0  [False, '66ea5116a642813c3dcf3c6f', None]
# 1  [False, '66ea5116a642813c3dcf3c6f', None]
# 2  [False, '66ea5116a642813c3dcf3c6f', None]
# 3  [False, '66ea5116a642813c3dcf3c6f', None]
# 4  [False, '66ea5116a642813c3dcf3c6f', None]
#
#                           transcript_id          new_topic  topic_order  \
# 0  01849238-f5f0-487e-bca4-7b4fe0c9625c  starting the call            1
# 1  01849238-f5f0-487e-bca4-7b4fe0c9625c           greeting            2
# 2  01849238-f5f0-487e-bca4-7b4fe0c9625c      introductions            3
# 3  01849238-f5f0-487e-bca4-7b4fe0c9625c             flying            4
# 4  01849238-f5f0-487e-bca4-7b4fe0c9625c          schooling            5
#
#    number_of_turns  topic_length  \
# 0                1         85.01
# 1                2          5.94
# 2                9         23.79
# 3               20         69.43
# 4                1          3.92
#
#                                           embeddings
# 0  [-0.07382959, 0.031588975, -0.07631215, -0.006...
# 1  [-0.09222623, 0.1348203, 0.090344675, 0.070808...
# 2  [-0.05392585, -0.021351758, -0.03909823, 0.054...
# 3  [0.057700507, 0.03469498, -0.028418075, 0.0820...
# 4  [0.022620993, 0.08201187, 0.026254188, 0.10571...

# %%
# kmeans on the new topic strings

# create new cluster data frames for 100 topics and 50 topics
cluster_100 = cluster
cluster_50 = cluster
cluster_25 = cluster

# 100 clusters
topic_array = np.array([np.array(x) for x in cluster['embeddings'].to_numpy()])
kmeans_topics_100 = sklearn.cluster.KMeans(n_clusters=100).fit(topic_array)
kmeans_labels_100 = kmeans_topics_100.predict(topic_array)
# bind labels back to cluster_100 and group based on what's being clustered together
cluster_100['clusters'] = kmeans_labels_100
#cluster_100.head()

# 50 clusters
topic_array = np.array([np.array(x) for x in cluster['embeddings'].to_numpy()])
kmeans_topics_50 = sklearn.cluster.KMeans(n_clusters=50).fit(topic_array)
kmeans_labels_50 = kmeans_topics_50.predict(topic_array)
# bind labels back to cluster_50 and group based on what's being clustered together
cluster_50['clusters'] = kmeans_labels_50
#cluster_50.head()

# 25 clusters
topic_array = np.array([np.array(x) for x in cluster['embeddings'].to_numpy()])
kmeans_topics_25 = sklearn.cluster.KMeans(n_clusters=25).fit(topic_array)
kmeans_labels_25 = kmeans_topics_25.predict(topic_array)
# bind labels back to cluster_25 and group based on what's being clustered together
cluster_25['clusters'] = kmeans_labels_25
#cluster_25.head()

# %%
# save 100 clusters
cluster_100 = cluster_100.sort_values(by = ['clusters'])
cluster_100.to_csv("/Users/helenschmidt/Library/CloudStorage/GoogleDrive-helenschmidt129@gmail.com/My Drive/SANLab/Experiments/Conversation-Structure/data/output/topic_clusters_100.csv", index = False)

# save 50 clusters
cluster_50 = cluster_50.sort_values(by = ['clusters'])
cluster_50.to_csv("/Users/helenschmidt/Library/CloudStorage/GoogleDrive-helenschmidt129@gmail.com/My Drive/SANLab/Experiments/Conversation-Structure/data/output/topic_clusters_50.csv", index = False)

# save 25 clusters
cluster_25 = cluster_25.sort_values(by = ['clusters'])
cluster_25.to_csv("/Users/helenschmidt/Library/CloudStorage/GoogleDrive-helenschmidt129@gmail.com/My Drive/SANLab/Experiments/Conversation-Structure/data/output/topic_clusters_25.csv", index = False)

# %% [markdown]
# ## TSNE on CLUSTERS

# %%
# now I want to get TSNE embeddings on cluster labels that I assigned groups of participant-provided labels
# see how close participant labels are to my clustered labels

# load cluster labels
# 50
cluster_label_50 = pd.read_csv("/Users/helenschmidt/Library/CloudStorage/GoogleDrive-helenschmidt129@gmail.com/My Drive/SANLab/Experiments/Conversation-Structure/data/output/topic_cluster_labels_50.csv")
# 25
cluster_label_25 = pd.read_csv("/Users/helenschmidt/Library/CloudStorage/GoogleDrive-helenschmidt129@gmail.com/My Drive/SANLab/Experiments/Conversation-Structure/data/output/topic_cluster_labels_25.csv")

# preview
cluster_label_25.head()
# Out:
#    clusters      cluster_label
# 0         0           politics
# 1         1           location
# 2         2            opinion
# 3         3         small talk
# 4         4  starting the call

# %%
# get embeddings on the cluster labels
def get_embeddings(row):
    # extract current label from the row
    current = row['cluster_label']
    # apply s-bert model to each string to get embeddings
    embeddings = model.encode(current)
    return embeddings

# save embeddings to output
cluster_label_50['embeddings'] = cluster_label_50.apply(get_embeddings, axis = 1)
# preview
cluster_label_50.head()
# Out:
#    clusters                          cluster_label  \
# 0         0            places, location, geography
# 1         1  background, daily life, relationships
# 2         2            school, college, university
# 3         3                money, expenses, saving
# 4         4                        vaccines, shots
#
#                                           embeddings
# 0  [0.115123995, -0.002396408, 0.012577971, 0.007...
# 1  [-0.014651105, 0.023957988, 0.026657121, 0.065...
# 2  [0.02738497, 0.026072375, 0.029432196, 0.02261...
# 3  [0.031809524, 0.10850602, -0.027284732, 0.0467...
# 4  [0.015072287, 0.07646736, 0.0045836503, -0.002...

# %%
# append a variable noting these are cluster labels
cluster_label_50['type'] = 'cluster'
# rename cluster_label to "topic"
cluster_label_50 = cluster_label_50.rename(columns = {'cluster_label':'topic'})
# preview
cluster_label_50.head()
# Out:
#    clusters                                  topic  \
# 0         0            places, location, geography
# 1         1  background, daily life, relationships
# 2         2            school, college, university
# 3         3                money, expenses, saving
# 4         4                        vaccines, shots
#
#                                           embeddings     type
# 0  [0.115123995, -0.002396408, 0.012577971, 0.007...  cluster
# 1  [-0.014651105, 0.023957988, 0.026657121, 0.065...  cluster
# 2  [0.02738497, 0.026072375, 0.029432196, 0.02261...  cluster
# 3  [0.031809524, 0.10850602, -0.027284732, 0.0467...  cluster
# 4  [0.015072287, 0.07646736, 0.0045836503, -0.002...  cluster

# %%
# now select clusters, new topic, and embeddings from cluster_50
cluster_50_subset = cluster_50[['clusters','new_topic','embeddings']]
# append a variable noting these are participant labels
cluster_50_subset['type'] = 'participant'
# rename new_topic to "topic"
cluster_50_subset = cluster_50_subset.rename(columns = {'new_topic':'topic'})
# preview
cluster_50_subset.head()
# Out:
# /var/folders/vj/qkpl_dxs7fd3f2nl6_9794n00000gn/T/ipykernel_31768/826036948.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster_50_subset['type'] = 'participant'
#        clusters                                        topic  \
# 3963          0                              where they live
# 16872         0  what texas is actually like for lgbt people
# 16873         0                            texan gun culture
# 14225         0                              soical distance
# 22879         0                           colorado residents
#
#                                               embeddings         type
# 3963   [0.04877898, 0.093149215, 0.002750613, 0.07424...  participant
# 16872  [0.048293743, -0.027363563, 0.06260574, 0.0918...  participant
# 16873  [0.021610662, 0.059049744, -0.047935188, 0.011...  participant
# 14225  [0.085162625, 0.01922674, -0.06977843, -0.0677...  participant
# 22879  [0.10372697, -0.041449253, 0.036547888, 0.0496...  participant

# %%
# concatenate cluster_label_50 and cluster_50_subset
tsne_50 = pd.concat([cluster_label_50, cluster_50_subset], ignore_index=True)
# preview
tsne_50.head(60)
# Out:
#     clusters                                        topic  \
# 0          0                  places, location, geography
# 1          1        background, daily life, relationships
# 2          2                  school, college, university
# 3          3                      money, expenses, saving
# 4          4                              vaccines, shots
# 5          5                 education, classes, teaching
# 6          6                   politics, voting, election
# 7          7                pandemic, illness, quarantine
# 8          8                          goodbyes, farewells
# 9          9                                     location
# 10        10                            starting the call
# 11        11                      animals, wildlife, pets
# 12        12                                sports, games
# 13        13            job, work, employment, occupation
# 14        14            job, work, employment, occupation
# 15        15                    children, kids, childhood
# 16        16               holidays, events, celebrations
# 17        17                    music, dance, instruments
# 18        18                               masks, masking
# 19        19                                         time
# 20        20                       greeting, introduction
# 21        21                                   small talk
# 22        22                 school, high school, classes
# 23        23                               pets, cat, dog
# 24        24  hobbies, activities, leisure, entertainment
# 25        25                        research, study, exam
# 26        26                       greeting, introduction
# 27        27                                         time
# 28        28               friends, family, relationships
# 29        29                                          age
# 30        30                rent, neighbor, home, housing
# 31        31                   career, profession, future
# 32        32                  television, podcasts, radio
# 33        33                weather, seasons, temperature
# 34        34         demographics, culture, global events
# 35        35                                     prolific
# 36        36                     user testing, experiment
# 37        37                       technical difficulties
# 38        38                                books, movies
# 39        39               friends, family, relationships
# 40        40          climate, weather, natural disasters
# 41        41                                   small talk
# 42        42                    food, drinks, restaurants
# 43        43                              covid, pandemic
# 44        44                                      surveys
# 45        45                                     lockdown
# 46        46                                     location
# 47        47                                        names
# 48        48                       travel, vacation, trip
# 49        49             technology, social media, online
# 50         0                              where they live
# 51         0  what texas is actually like for lgbt people
# 52         0                            texan gun culture
# 53         0                              soical distance
# 54         0                           colorado residents
# 55         0             the geographic area person is at
# 56         0                               how's new york
# 57         0                             museums location
# 58         0                               vacation spots
# 59         0                              where are they?
#
#                                            embeddings         type
# 0   [0.115123995, -0.002396408, 0.012577971, 0.007...      cluster
# 1   [-0.014651105, 0.023957988, 0.026657121, 0.065...      cluster
# 2   [0.02738497, 0.026072375, 0.029432196, 0.02261...      cluster
# 3   [0.031809524, 0.10850602, -0.027284732, 0.0467...      cluster
# 4   [0.015072287, 0.07646736, 0.0045836503, -0.002...      cluster
# 5   [0.057258613, 0.015636563, -0.008564341, 0.047...      cluster
# 6   [0.01678374, 0.009973231, 0.03967316, -0.00118...      cluster
# 7   [0.02846067, 0.016469527, 0.019100389, -0.0011...      cluster
# 8   [0.02785908, 0.102045484, 0.08101375, 0.019764...      cluster
# 9   [0.039457366, 0.027397515, -0.005985808, 0.016...      cluster
# 10  [-0.07382959, 0.031588975, -0.07631215, -0.006...      cluster
# 11  [0.023932287, 0.0026213927, 0.07638643, 0.0348...      cluster
# 12  [0.052969944, 0.04313419, -0.015954725, -0.030...      cluster
# 13  [0.023154972, 0.03973687, 0.030035375, -0.0094...      cluster
# 14  [0.023154972, 0.03973687, 0.030035375, -0.0094...      cluster
# 15  [-0.029942058, 0.08370242, 0.040818132, 0.0437...      cluster
# 16  [0.070344955, 0.12059731, 0.030437019, 0.02947...      cluster
# 17  [0.054420017, -0.07635325, 0.042705793, -0.053...      cluster
# 18  [0.029186487, 0.08164016, 0.03522907, 0.043131...      cluster
# 19  [-0.07450688, 0.054837935, -0.021195365, 0.020...      cluster
# 20  [-0.06635827, 0.14401491, 0.031952623, 0.03601...      cluster
# 21  [0.029553043, 0.09422553, 0.04386391, 0.034728...      cluster
# 22  [0.008839094, 0.02734736, 0.03989502, 0.009426...      cluster
# 23  [0.021454794, -0.007315885, 0.059746094, 0.034...      cluster
# 24  [0.07665718, 0.007924699, 0.038050547, -0.0052...      cluster
# 25  [0.06323367, 0.07119233, -0.033091724, 0.04552...      cluster
# 26  [-0.06635827, 0.14401491, 0.031952623, 0.03601...      cluster
# 27  [-0.07450688, 0.054837935, -0.021195365, 0.020...      cluster
# 28  [-0.08515848, 0.08707859, 0.0146143995, 0.0304...      cluster
# 29  [-0.0076686614, 0.08090485, -0.0427228, 0.0111...      cluster
# 30  [0.04203828, -0.03992738, 0.025957262, 0.01174...      cluster
# 31  [-0.032877415, 0.057623565, -0.012386552, 0.02...      cluster
# 32  [0.07421346, -0.083416134, 0.0040188553, -0.05...      cluster
# 33  [0.00039427137, 0.006355695, 0.031694315, 0.10...      cluster
# 34  [0.10744989, 0.01556631, 0.03778815, 0.0346492...      cluster
# 35  [0.093884766, -0.008704644, -0.009217696, 0.03...      cluster
# 36  [0.0050981105, -0.009186512, -0.0035255034, -0...      cluster
# 37  [0.013464501, -0.021109253, 0.03793236, -0.010...      cluster
# 38  [-0.019647198, -0.036983136, -0.0087717455, 0....      cluster
# 39  [-0.08515848, 0.08707859, 0.0146143995, 0.0304...      cluster
# 40  [0.04210667, -0.01417913, 0.10641357, 0.056224...      cluster
# 41  [0.029553043, 0.09422553, 0.04386391, 0.034728...      cluster
# 42  [0.032154527, -0.020021804, 0.042249527, 0.067...      cluster
# 43  [0.0034332855, 0.010726219, -0.011669753, -0.0...      cluster
# 44  [-0.05208781, -0.029460708, 0.018374184, 0.101...      cluster
# 45  [-0.08583782, 0.044101816, -0.06541019, 0.0157...      cluster
# 46  [0.039457366, 0.027397515, -0.005985808, 0.016...      cluster
# 47  [-0.08666404, 0.0077697937, -0.058554053, 0.05...      cluster
# 48  [0.06606161, 0.0031766722, 0.032061476, 0.0365...      cluster
# 49  [0.046754938, -0.032546233, 0.006806531, -0.02...      cluster
# 50  [0.04877898, 0.093149215, 0.002750613, 0.07424...  participant
# 51  [0.048293743, -0.027363563, 0.06260574, 0.0918...  participant
# 52  [0.021610662, 0.059049744, -0.047935188, 0.011...  participant
# 53  [0.085162625, 0.01922674, -0.06977843, -0.0677...  participant
# 54  [0.10372697, -0.041449253, 0.036547888, 0.0496...  participant
# 55  [0.082848184, 0.07011282, 0.018449008, -0.0499...  participant
# 56  [0.081395224, -0.04006311, 0.0932506, 0.020177...  participant
# 57  [0.040784776, 0.08600087, -0.054241955, 0.0338...  participant
# 58  [0.08337394, -0.021047637, 0.0552868, 0.048446...  participant
# 59  [-0.07478545, 0.060378794, -0.011022544, 0.091...  participant

# %%
# now apply tsne to reduce embeddings to 2D space
tsne_50_embeddings = np.stack(tsne_50['embeddings'].values)
tsne_50_results = tsne.fit_transform(tsne_50_embeddings)
tsne_50_df = pd.DataFrame(tsne_50_results, columns = ['tsne_1','tsne_2'])
tsne_50_df = pd.concat([tsne_50, tsne_50_df], axis = 1)

# save
tsne_50_df.to_csv("/Users/helenschmidt/Library/CloudStorage/GoogleDrive-helenschmidt129@gmail.com/My Drive/SANLab/Experiments/Conversation-Structure/data/output/tsne_50.csv", index = False)

# preview
tsne_50_df.head()
# Out:
#    clusters                                  topic  \
# 0         0            places, location, geography
# 1         1  background, daily life, relationships
# 2         2            school, college, university
# 3         3                money, expenses, saving
# 4         4                        vaccines, shots
#
#                                           embeddings     type     tsne_1  \
# 0  [0.115123995, -0.002396408, 0.012577971, 0.007...  cluster -85.771576
# 1  [-0.014651105, 0.023957988, 0.026657121, 0.065...  cluster  53.737900
# 2  [0.02738497, 0.026072375, 0.029432196, 0.02261...  cluster -76.254822
# 3  [0.031809524, 0.10850602, -0.027284732, 0.0467...  cluster -24.427193
# 4  [0.015072287, 0.07646736, 0.0045836503, -0.002...  cluster -28.157076
#
#        tsne_2
# 0   12.990308
# 1    1.947843
# 2  -42.545815
# 3  -10.131094
# 4  106.668648

# %% [markdown]
# # Archive
