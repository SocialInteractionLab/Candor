# %%
import os
import json
import ast
import pandas as pd
import matplotlib as plt

# %%
folder_path = 'demographic_data'
files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]
dataframes = []

for file in files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    dataframes.append(df)

combined_df = pd.concat(dataframes, ignore_index=True)
filtered_df = combined_df[combined_df['Status'] == "APPROVED"]

filtered_df.to_csv('demographic_combined.csv', index=False)

print("All files have been combined into 'demographic_combined.csv'.")
# Out:
# All files have been combined into 'demographic_combined.csv'.

# %%
# Load the first CSV file and extract unique values
file1_path = "denseSubset_all.csv"  # Replace with your actual file path
df1 = pd.read_csv(file1_path)

df1["participent_id_list"] = df1["participent_id"].apply(ast.literal_eval)  # Convert string to list
unique_values = set(item for sublist in df1["participent_id_list"] for item in sublist)

print(len(unique_values))
# Load the second CSV file
file2_path = "demographic_combined.csv"  # Replace with your actual file path
df2 = pd.read_csv(file2_path)

# Filter the second dataframe based on unique values from the first file
filtered_df = df2[df2["Participant id"].isin(unique_values)]

# Save the filtered data to a new CSV file
filtered_df.to_csv("filtered_demographic.csv", index=False)

# Display filtered data
print(filtered_df)
# Out:
# 1853
#                  Submission id            Participant id    Status  \
# 11    66e3639f0ec61aeee8b66fc4  5c686a5e77b2860001752a61  APPROVED
# 15    67662d34d4c469876a2c5525  669bbdcdb3fe0784d521b666  APPROVED
# 16    67662d3c3edcb9fc930b7935  5ec87daedce2260008f5c0d3  APPROVED
# 18    67662dd02dde32ea7b0b59ef  673b25f4fc8a81345363741e  APPROVED
# 19    67662dec1655641b93a2d6bf  6110a4e91e5bc7a89d9ac722  APPROVED
# ...                        ...                       ...       ...
# 1945  673d768b9b7076ea013a018f  671a75730f099b1793f93951  APPROVED
# 1946  673d796069b41a42a1fa9d21  672f9ea5879c7e9e8a73398f  APPROVED
# 1947  673d797b83c953b693453be6  6734010bda95d208801d15b0  APPROVED
# 1948  673d81efabfeebf0f1ac3ded  672864f4d190dad96fcdc6e6  APPROVED
# 1949  673d9188e7ba7b58595082a6  6731fbcdb6e9972cb47888ba  APPROVED
#
#      Custom study tncs accepted at                   Started at  \
# 11                  Not Applicable  2024-09-12T21:56:52.332000Z
# 15                  Not Applicable  2024-12-21T02:51:37.103000Z
# 16                  Not Applicable  2024-12-21T02:51:59.332000Z
# 18                  Not Applicable  2024-12-21T02:54:15.948000Z
# 19                  Not Applicable  2024-12-21T02:54:50.678000Z
# ...                            ...                          ...
# 1945                Not Applicable  2024-11-20T05:41:58.545000Z
# 1946                Not Applicable  2024-11-20T05:53:47.369000Z
# 1947                Not Applicable  2024-11-20T05:54:39.731000Z
# 1948                Not Applicable  2024-11-20T06:30:18.097000Z
# 1949                Not Applicable  2024-11-20T07:37:05.323000Z
#
#                      Completed at                  Reviewed at  \
# 11    2024-09-12T22:33:40.231000Z  2024-09-12T22:33:56.135000Z
# 15    2024-12-21T03:03:43.623000Z  2024-12-21T03:03:46.135000Z
# 16    2024-12-21T03:30:21.694000Z  2024-12-21T03:30:22.770000Z
# 18    2024-12-21T03:07:18.463000Z  2024-12-21T03:07:19.279000Z
# 19    2024-12-21T03:23:17.064000Z  2024-12-21T03:23:17.804000Z
# ...                           ...                          ...
# 1945  2024-11-20T06:20:33.550000Z  2024-11-20T06:20:36.981000Z
# 1946  2024-11-20T06:32:21.085000Z  2024-11-20T06:33:24.118000Z
# 1947  2024-11-20T06:22:05.848000Z  2024-11-20T06:25:21.471000Z
# 1948  2024-11-20T07:30:25.278000Z  2024-11-20T15:55:34.570000Z
# 1949  2024-11-20T08:30:32.292000Z  2024-11-20T15:55:35.970000Z
#
#                       Archived at  Time taken Completion code  ...  \
# 11    2024-09-12T22:33:41.214438Z      2208.0        C1GEJ4PE  ...
# 15    2024-12-21T03:03:44.450131Z       727.0        C1FFQ6DB  ...
# 16    2024-12-21T03:30:22.594736Z      2303.0        C1FFQ6DB  ...
# 18    2024-12-21T03:07:19.199537Z       783.0        C1FFQ6DB  ...
# 19    2024-12-21T03:23:17.729252Z      1707.0        C1FFQ6DB  ...
# ...                           ...         ...             ...  ...
# 1945  2024-11-20T06:20:34.497654Z      2316.0        C1FFQ6DB  ...
# 1946  2024-11-20T06:32:21.716689Z      2314.0        C1FFQ6DB  ...
# 1947  2024-11-20T06:25:20.637899Z      1647.0        C1FFQ6DB  ...
# 1948  2024-11-20T07:36:08.405148Z      3608.0       C1FFQ6DB.  ...
# 1949  2024-11-20T08:30:33.259055Z      3207.0       C1FFQ6DB.  ...
#
#                        Fluent languages Age                Sex  \
# 11                              English  30             Female
# 15                              English  18             Female
# 16    Chinese, English, Korean, Spanish  24             Female
# 18                              English  21  Prefer not to say
# 19                              English  40             Female
# ...                                 ...  ..                ...
# 1945                            English  27             Female
# 1946                   English, Swahili  42             Female
# 1947                            English  29             Female
# 1948                            English  24             Female
# 1949                   English, Swahili  25             Female
#
#      Ethnicity simplified Country of birth Country of residence  \
# 11                  White           Canada               Canada
# 15                  Mixed           Canada               Canada
# 16                  Asian            China               Canada
# 18                  White   United Kingdom       United Kingdom
# 19                  Other    United States        United States
# ...                   ...              ...                  ...
# 1945                Black            Kenya       United Kingdom
# 1946                Black            Kenya        United States
# 1947         DATA_EXPIRED    United States        United States
# 1948                White    United States        United States
# 1949                Black            Kenya       United Kingdom
#
#          Nationality  Language Student status  \
# 11            Canada   English   DATA_EXPIRED
# 15            Canada   English            Yes
# 16            Canada  Mandarin            Yes
# 18    United Kingdom   English             No
# 19     United States   English             No
# ...              ...       ...            ...
# 1945  United Kingdom   English             No
# 1946   United States   English             No
# 1947   United States   English             No
# 1948   United States   English             No
# 1949  United Kingdom   English            Yes
#
#                                       Employment status
# 11                                         DATA_EXPIRED
# 15                         Unemployed (and job seeking)
# 16                                            Full-Time
# 18    Not in paid work (e.g. homemaker', 'retired or...
# 19                                         DATA_EXPIRED
# ...                                                 ...
# 1945                                          Full-Time
# 1946                                          Part-Time
# 1947                                       DATA_EXPIRED
# 1948                                          Full-Time
# 1949                                          Full-Time
#
# [1757 rows x 21 columns]

# %%
folder_path = 'postSurvey'
files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]
dataframes = []

for file in files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    
    # Ensure "exit" column exists before filtering
    if "exitSurvey" in df.columns:
        df = df.dropna(subset=["exitSurvey"])  # Remove rows where "exit" is NaN
        df = df[df["exitSurvey"].astype(str).str.strip() != ""]  # Remove rows where "exit" is empty
    
    dataframes.append(df)

# Combine all dataframes
combined_df = pd.concat(dataframes, ignore_index=True)

# Remove duplicate rows
combined_df = combined_df.drop_duplicates()

combined_df = combined_df[combined_df["participantIdentifier"].isin(unique_values)]

print (combined_df)

combined_df["exitSurvey"] = combined_df["exitSurvey"].apply(json.loads)

combined_df = combined_df.join(pd.json_normalize(combined_df["exitSurvey"]))

id_to_change = combined_df[combined_df["gender"].astype(str).str.strip() == "non-binary"]["participantIdentifier"]

filtered_df.loc[filtered_df["Participant id"].isin(id_to_change), "Sex"] = "non-binary"
# Out:
#                               id       ended              endedLastChangedAt  \
# 0     01JFKM7A7J6N3XZTX1DCJAJ28P  game ended  2024-12-21T03:42:52.327679442Z
# 1     01JFKTAVB51SM1XJSBT816MQ7G  game ended  2024-12-21T06:15:13.810407672Z
# 2     01JFKM6QEY170K66ZKX69T9CVJ  game ended  2024-12-21T03:57:27.686606361Z
# 3     01JFKQ34730WS8QQHVKK41S8N7  game ended  2024-12-21T04:39:50.520352758Z
# 5     01JFKKVER1EFTM6QM5EPM4VDCF  game ended  2024-12-21T03:39:08.389428059Z
# ...                          ...         ...                             ...
# 1902  01JF1M3DTJ2Y07175ZARW7X9P0  game ended  2024-12-14T04:23:55.495981257Z
# 1903  01JF1NJHQV2WC6DSZ76E35M1E7  game ended   2024-12-14T04:29:35.11441223Z
# 1904  01JF1J5MK0PBY39T2KQH0Z2HD8  game ended  2024-12-14T03:20:04.127337463Z
# 1905  01JF1JFV5T3H28AW663XDK13NK  game ended  2024-12-14T04:15:15.945141574Z
# 1906  01JF1V8P03SXGY5B7H82WSYJDN  game ended  2024-12-14T06:20:29.817117164Z
#
#       exitStep           exitStepLastChangedAt  \
# 0          1.0  2024-12-21T03:43:56.700346095Z
# 1          1.0  2024-12-21T06:16:20.747551987Z
# 2          1.0  2024-12-21T03:58:07.935276741Z
# 3          1.0   2024-12-21T04:40:17.87028361Z
# 5          1.0  2024-12-21T03:39:41.618521099Z
# ...        ...                             ...
# 1902       1.0  2024-12-14T04:25:52.176003379Z
# 1903       1.0  2024-12-14T04:29:59.430680551Z
# 1904       1.0  2024-12-14T03:20:34.598712543Z
# 1905       1.0  2024-12-14T04:16:48.136487474Z
# 1906       1.0  2024-12-14T06:21:26.819025772Z
#
#                                              exitSurvey  \
# 0     {"age":"19","gender":"","strength":"","fair":"...
# 1     {"age":"23","gender":"","strength":"","fair":"...
# 2     {"age":"66","gender":"female","strength":"","f...
# 3     {"age":"44","gender":"","strength":"","fair":"...
# 5     {"age":"50","gender":"","strength":"","fair":"...
# ...                                                 ...
# 1902  {"age":"52","gender":"female","strength":"","f...
# 1903  {"age":"37","gender":"","strength":"","fair":"...
# 1904  {"age":"","gender":"female","strength":"","fai...
# 1905  {"age":"47","gender":"female","strength":"","f...
# 1906  {"age":"30","gender":"female","strength":"","f...
#
#              exitSurveyLastChangedAt                      gameID  \
# 0     2024-12-21T03:43:56.656363039Z  01JFKHSZHWSR9BWC8YDCTF5BYX
# 1     2024-12-21T06:16:20.597625396Z  01JFKHSZM31HNAKMPWJ3NYKM7E
# 2     2024-12-21T03:58:07.859112866Z  01JFKHSZJA2SMG54JD72S1S3J4
# 3     2024-12-21T04:40:17.784545597Z  01JFKHSZJNR3Q3TQRNG8Q5AFBE
# 5     2024-12-21T03:39:41.523892568Z  01JFKHSZGVQADMTST80NP0ZBRJ
# ...                              ...                         ...
# 1902  2024-12-14T04:25:52.090862352Z  01JF1HHXP7DXRFGCKY1V1VP55K
# 1903  2024-12-14T04:29:59.272461186Z  01JF1HHXP93CWBV2FAQYZ3QSG9
# 1904  2024-12-14T03:20:34.511912056Z  01JF1HHXM5ENSW28YNY0W5NZNP
# 1905  2024-12-14T04:16:48.036128799Z  01JF1HHXMVQF6NM1WS36X5AZDA
# 1906  2024-12-14T06:21:26.793004577Z  01JF1N9MD9HPPJDQDCV8ZS9M4D
#
#                  gameIDLastChangedAt introDone  ...  \
# 0     2024-12-21T03:29:51.472147826Z      True  ...
# 1     2024-12-21T05:16:38.758317379Z      True  ...
# 2     2024-12-21T03:29:32.140585224Z      True  ...
# 3     2024-12-21T04:19:59.908458865Z      True  ...
# 5     2024-12-21T03:23:22.777964731Z      True  ...
# ...                              ...       ...  ...
# 1902  2024-12-14T03:41:24.199561712Z      True  ...
# 1903  2024-12-14T04:07:08.499482601Z      True  ...
# 1904  2024-12-14T03:07:54.178537703Z      True  ...
# 1905  2024-12-14T03:13:13.923226049Z      True  ...
# 1906  2024-12-14T05:46:36.620925204Z      True  ...
#
#                    participantID      participantIDLastChangedAt  \
# 0     01JFKM79CRKPXADRY1WP6W8K3G  2024-12-21T03:29:51.346182229Z
# 1     01JFKT93Y5Y8DGXYKFMCVBQBKN  2024-12-21T05:16:38.629323242Z
# 2     01JFKM6Q57320SRT9BYHRC1ZHP  2024-12-21T03:29:32.126350651Z
# 3     01JFKQ343BSK5V4ZZS08KVE5H1  2024-12-21T04:19:59.843856628Z
# 5     01JFKKVEBVRVDFEBV5WBPZJPDC  2024-12-21T03:23:22.753788373Z
# ...                          ...                             ...
# 1902  01JF1M3DERKE1Q3RBA7EVRR0N7  2024-12-14T03:41:24.178557617Z
# 1903  01JF1NJGYVTHMN7KNJW23904R8  2024-12-14T04:07:08.283698648Z
# 1904  01JF1J5M8MR7JP1126CWRG1J7H  2024-12-14T03:07:39.488885492Z
# 1905  01JF1JFTRMHJZ3AX67H3HZFD2C  2024-12-14T03:13:13.914792789Z
# 1906  01JF1V8NJJ4N5PM71971GA2RDM  2024-12-14T05:46:36.419513305Z
#
#          participantIdentifier participantIdentifierLastChangedAt  \
# 0     664269a23754e837eca64376     2024-12-21T03:29:51.346182229Z
# 1     675993e54c5648a5ba804784     2024-12-21T05:16:38.629323242Z
# 2     5f489766dbc4a2364c0f4f93     2024-12-21T03:29:32.126350651Z
# 3     669c8c8b4198ea65c9d917ef     2024-12-21T04:19:59.843856628Z
# 5     668173282d968e44eb1c041a     2024-12-21T03:23:22.753788373Z
# ...                        ...                                ...
# 1902  67328c7c93419796b690a4dc     2024-12-14T03:41:24.178557617Z
# 1903  672ee097180c3f2689355231     2024-12-14T04:07:08.283698648Z
# 1904  66a7f152afdfdddf06dfc0b3     2024-12-14T03:07:39.488885492Z
# 1905  5e29fd5f2bec3b065e9a729e     2024-12-14T03:13:13.914792789Z
# 1906  60c8467d9872c0d83f695499     2024-12-14T05:46:36.419513305Z
#
#                                  treatment          treatmentLastChangedAt  \
# 0       {"fileNumber":168,"playerCount":1}  2024-12-21T03:29:51.472147826Z
# 1       {"fileNumber":178,"playerCount":1}  2024-12-21T05:16:38.758317379Z
# 2       {"fileNumber":144,"playerCount":1}  2024-12-21T03:29:32.140585224Z
# 3       {"fileNumber":181,"playerCount":1}  2024-12-21T04:19:59.908458865Z
# 5       {"fileNumber":199,"playerCount":1}  2024-12-21T03:23:22.777964731Z
# ...                                    ...                             ...
# 1902  {"opinion":"slider","playerCount":1}  2024-12-14T03:41:24.199561712Z
# 1903  {"opinion":"slider","playerCount":1}  2024-12-14T04:07:08.499482601Z
# 1904  {"opinion":"slider","playerCount":1}  2024-12-14T03:07:39.499419056Z
# 1905  {"opinion":"slider","playerCount":1}  2024-12-14T03:13:13.923226049Z
# 1906  {"opinion":"slider","playerCount":1}  2024-12-14T05:46:36.620925204Z
#
#      treatmentName      treatmentNameLastChangedAt  \
# 0          file168  2024-12-21T03:29:51.472147826Z
# 1          file178  2024-12-21T05:16:38.758317379Z
# 2          file144  2024-12-21T03:29:32.140585224Z
# 3          file181  2024-12-21T04:19:59.908458865Z
# 5          file199  2024-12-21T03:23:22.777964731Z
# ...            ...                             ...
# 1902   experiment1  2024-12-14T03:41:24.199561712Z
# 1903   experiment1  2024-12-14T04:07:08.499482601Z
# 1904   experiment1  2024-12-14T03:07:39.499419056Z
# 1905   experiment1  2024-12-14T03:13:13.923226049Z
# 1906   experiment1  2024-12-14T05:46:36.620925204Z
#
#                                               urlParams  \
# 0     {"PROLIFIC_PID":"664269a23754e837eca64376","ST...
# 1     {"PROLIFIC_PID":"675993e54c5648a5ba804784","ST...
# 2     {"PROLIFIC_PID":"5f489766dbc4a2364c0f4f93","ST...
# 3     {"PROLIFIC_PID":"669c8c8b4198ea65c9d917ef","ST...
# 5     {"PROLIFIC_PID":"668173282d968e44eb1c041a","ST...
# ...                                                 ...
# 1902  {"PROLIFIC_PID":"67328c7c93419796b690a4dc","ST...
# 1903  {"PROLIFIC_PID":"672ee097180c3f2689355231","ST...
# 1904  {"PROLIFIC_PID":"66a7f152afdfdddf06dfc0b3","ST...
# 1905  {"PROLIFIC_PID":"5e29fd5f2bec3b065e9a729e","ST...
# 1906  {"PROLIFIC_PID":"60c8467d9872c0d83f695499","ST...
#
#               urlParamsLastChangedAt
# 0     2024-12-21T03:29:51.747894068Z
# 1     2024-12-21T05:16:59.951658889Z
# 2     2024-12-21T03:29:32.294748736Z
# 3     2024-12-21T04:19:59.967000464Z
# 5      2024-12-21T03:23:22.98757292Z
# ...                              ...
# 1902  2024-12-14T03:41:24.362011998Z
# 1903  2024-12-14T04:07:08.806377593Z
# 1904  2024-12-14T03:07:39.662701385Z
# 1905  2024-12-14T03:13:14.144836983Z
# 1906  2024-12-14T05:46:36.960045041Z
#
# [1578 rows x 21 columns]

# %%
filtered_gender = combined_df[combined_df["gender"].astype(str).str.strip().ne("") & combined_df["gender"].notna()]["gender"]
print(filtered_gender)

sex_d = pd.DataFrame(filtered_gender.describe())
print(sex_d)

# Count of each category in the "gender" column
sex_c = filtered_gender.value_counts()
print("\nCount of each category in 'gender':")
print(sex_c)


# sex_d = pd.DataFrame(combined_df['gender'].describe(include='object'))
# print(sex_d)

# # Count of Each Category
# sex_c = combined_df['gender'].value_counts()
# print("\nCount of each category in 'Sex':")
# print(sex_c)
# Out:
# 2       female
# 6       female
# 10      female
# 12      female
# 13      female
#          ...
# 1571    female
# 1572    female
# 1573    female
# 1575    female
# 1577    female
# Name: gender, Length: 605, dtype: object
#         gender
# count      605
# unique       3
# top     female
# freq       582
#
# Count of each category in 'gender':
# gender
# female        582
# non-binary     22
# male            1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

file_path = 'filtered_demographic.csv'
# data = pd.read_csv(file_path)
data = filtered_df

# Choose the column to plot

value_counts = data['Nationality'].value_counts()

# Convert to DataFrame for tabular display
nationality_counts_df = value_counts.reset_index()
nationality_counts_df.columns = ["Nationality", "Count"]

# Display the count table
print(nationality_counts_df.to_string(index=False))  # Prints table in a readable format

# Generate the pie chart with counts in labels
plt.figure(figsize=(8, 8))
plt.pie(value_counts, 
        labels=[f"{idx} ({count})" for idx, count in zip(value_counts.index, value_counts.values)], 
        autopct='%1.1f%%', 
        startangle=90)

# Add title
plt.title('Pie Chart of Nationality Counts')
plt.axis('equal')  # Ensures the pie chart is circular

# Show the chart
plt.show()
# Out:
#                       Nationality  Count
#                     United States    930
#                    United Kingdom    341
#                            Canada    242
#                           Nigeria    103
#                             India     16
#                             China     11
#                       Philippines     11
#                      DATA_EXPIRED      8
#                          Pakistan      7
#                           Ireland      6
#                             Kenya      6
#                        Bangladesh      5
#                             Ghana      5
#                            Poland      4
#                            Turkey      4
#                           Vietnam      3
#                         Australia      3
#                             Italy      3
#                             Spain      2
#                          Bulgaria      2
#                            France      2
#                          Zimbabwe      2
#                           Germany      2
#                             Nepal      2
#                Russian Federation      2
#                           Romania      2
#                         Sri Lanka      2
#                            Mexico      2
#                          Suriname      1
#                              Fiji      1
#                             Korea      1
#                           Armenia      1
#                           Tunisia      1
#                         Singapore      1
#                           Jamaica      1
#                         Lithuania      1
#                           Hungary      1
#                              Iran      1
#                            Zambia      1
#                             Japan      1
#                            Jordan      1
#                          Ethiopia      1
#                            Greece      1
#                              Cuba      1
#                           Belgium      1
#                           Ukraine      1
#                         Hong Kong      1
#                           Algeria      1
#                          Barbados      1
#                            Israel      1
#              Syrian Arab Republic      1
#                            Uganda      1
#                         Macedonia      1
#                          Portugal      1
# Venezuela, Bolivarian Republic of      1
#                        Madagascar      1
#                          Cameroon      1

# %%
value_counts_eth = data['Ethnicity simplified'].value_counts()

# Convert to DataFrame
ethnicity_counts_df = value_counts_eth.reset_index()
ethnicity_counts_df.columns = ["Ethnicity", "Count"]

# Display the count table in the console
print(ethnicity_counts_df.to_string(index=False))  # Prints table in a readable format

# Generate the pie chart with counts in labels
plt.figure(figsize=(8, 8))
plt.pie(value_counts_eth, 
        labels=[f"{idx} ({count})" for idx, count in zip(value_counts_eth.index, value_counts_eth.values)], 
        autopct='%1.1f%%', 
        startangle=90)

# Add title
plt.title('Pie Chart of Ethnicity Counts')
plt.axis('equal')  # Ensures the pie chart is circular

# Show the chart
plt.show()
# Out:
#    Ethnicity  Count
#        White    946
#        Black    364
#        Asian    238
#        Mixed    129
#        Other     64
# DATA_EXPIRED     16

# %%
value_counts_emp = data['Employment status'].value_counts()

emp_counts_df = value_counts_emp.reset_index()
emp_counts_df.columns = ["Employment status", "Count"]

# Display the count table
print(emp_counts_df.to_string(index=False))  # Prints table in a readable format

# Generate the pie chart with counts in labels
plt.figure(figsize=(8, 8))
plt.pie(value_counts_emp, 
        labels=[f"{idx} ({count})" for idx, count in zip(value_counts_emp.index, value_counts_emp.values)], 
        autopct='%1.1f%%', 
        startangle=90)

# Add title
plt.title('Pie Chart of Employment status Counts')
plt.axis('equal')  # Ensures the pie chart is circular

# Show the chart
plt.show()
# Out:
#                                        Employment status  Count
#                                                Full-Time    773
#                                                Part-Time    348
#                                             DATA_EXPIRED    254
#                             Unemployed (and job seeking)    178
# Not in paid work (e.g. homemaker', 'retired or disabled)    125
#                                                    Other     67
#             Due to start a new job within the next month     12

# %%
# print(pd.DataFrame(data['Sex'].describe(include='object')))

# General Description
sex_description = pd.DataFrame(data['Sex'].describe(include='object'))
print(sex_description)

# Count of Each Category
sex_counts = data['Sex'].value_counts()
print("\nCount of each category in 'Sex':")
print(sex_counts)

# Get Only Female Count
female_count = sex_counts.get('Female', 0)  # Default to 0 if 'Female' is missing
print(f"\nTotal Female Count: {female_count}")
# Out:
#          Sex
# count   1757
# unique     5
# top     Male
# freq     869
#
# Count of each category in 'Sex':
# Sex
# Male                 869
# Female               851
# non-binary            22
# Prefer not to say     12
# DATA_EXPIRED           3
# Name: count, dtype: int64
#
# Total Female Count: 851

# %%
# print (data['Age'].describe)
print(pd.DataFrame(data['Age']).describe())
# print(type(data))
plt.figure(figsize=(8, 6))
plt.boxplot(data['Age'], vert=True, patch_artist=True, labels=['Age'])
plt.title('Box Plot of Age')
plt.ylabel('Value')
plt.show()
# Out:
#                Age
# count  1757.000000
# mean     35.161070
# std      12.333156
# min      18.000000
# 25%      26.000000
# 50%      32.000000
# 75%      42.000000
# max     105.000000
